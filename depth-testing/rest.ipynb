# %%
from skspatial.objects import Plane
from skspatial.objects import Points
from skspatial.plotting import plot_3d


points = Points([[0, 0, 0], [1, 3, 5], [-5, 6, 3], [3, 6, 7], [-2, 6, 7]])

plane = Plane.best_fit(points)

print(plane)
plot_3d(
    points.plotter(c='k', s=50, depthshade=False),
    plane.plotter(alpha=0.2, lims_x=(-5, 5), lims_y=(-5, 5)),
)
# Out:
# Plane(point=Point([-0.6,  4.2,  4.4]), normal=Vector([-0.35081243, -0.69449919,  0.62817315]))
# (<Figure size 432x288 with 1 Axes>, <Axes3DSubplot:>)

# %%
# !python3 -m pip install scikit-spatial
# Out:
# Requirement already satisfied: scikit-spatial in /usr/local/lib/python3.9/site-packages (6.0.1)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.9/site-packages (from scikit-spatial) (1.20.3)
# Requirement already satisfied: matplotlib<4,>=3 in /usr/local/lib/python3.9/site-packages (from scikit-spatial) (3.4.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib<4,>=3->scikit-spatial) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib<4,>=3->scikit-spatial) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/site-packages (from matplotlib<4,>=3->scikit-spatial) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib<4,>=3->scikit-spatial) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/site-packages (from matplotlib<4,>=3->scikit-spatial) (2.8.1)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.15.8/libexec/lib/python3.9/site-packages (from cycler>=0.10->matplotlib<4,>=3->scikit-spatial) (1.15.0)
